# %%
import pandas as pd

# %%
med = pd.read_csv("medicamentos.csv", sep=';', encoding='latin-1')
med.head()
# Out:
#   Principio activo Potencia Unidad de potencia  Unidades      Tipo  \
# 0     acenocumarol        4                 mg        20  unidades
# 1      allopurinol      100                 mg        30  unidades
# 2      allopurinol      100                 mg        60  unidades
# 3      allopurinol      300                 mg        20  unidades
# 4      allopurinol      300                 mg        30  unidades
#
#                        Forma farmacéutica Precio de referencia
# 0  Comprimidos/Pastillas/Tabletas/Grageas           $ 2.635,90
# 1  Comprimidos/Pastillas/Tabletas/Grageas             $ 441,12
# 2  Comprimidos/Pastillas/Tabletas/Grageas             $ 826,54
# 3  Comprimidos/Pastillas/Tabletas/Grageas             $ 958,53
# 4  Comprimidos/Pastillas/Tabletas/Grageas           $ 1.015,56

# %%
med[["Principio activo","Potencia","Unidades"]].head()
# Out:
#   Principio activo Potencia  Unidades
# 0     acenocumarol        4        20
# 1      allopurinol      100        30
# 2      allopurinol      100        60
# 3      allopurinol      300        20
# 4      allopurinol      300        30
